# %%
int = 29
print(type(int))
# Out:
# <class 'int'>

# %% [markdown]
# int

# %%
float = 10.5
print(type(float))
# Out:
# <class 'float'>

# %% [markdown]
# float

# %%
complex = 3+3j
print(type(complex))
# Out:
# <class 'complex'>

# %% [markdown]
# complex

# %%
inn = 10
print(float(inn))
print(type(inn))
# Out:
# 10.0
# <class 'int'>

# %% [markdown]
# int to float

# %%
a = 20
b = 10
print(a + b)
print(a - b)
print(a * b)
print(a / b)
print(a ** b)
print(a % b)
print(a // b)
# Out:
# 30
# 10
# 200
# 2.0
# 10240000000000
# 0
# 2

# %%
a = 20
b = 20
print(a > b)
print(a < b)
print(a == b)
print(a != b)
print(a >= b)
print(a <+ b)
# Out:
# False
# False
# True
# False
# True
# False

# %%
import math
print(math.ceil(10.4))
print(math.floor(20.5))
print(math.gcd(3,6,9,12))
# Out:
# 11
# 20
# 3

# %%
a = "pradeep"
print(a)
# Out:
# pradeep

# %%
text1 = "It's me pradeep"
text2 = '"hello" pradeep'
print(text1)
print(text2)
# Out:
# It's me pradeep
# "hello" pradeep

# %%
a = "i am"
b = "pradeep"
print(a + " " + b)
print(a * 3)
# Out:
# i am pradeep
# i ami ami am

# %%
data = "pradeep"
print(data[2])
print(data[-3])
# Out:
# a
# e

# %%
name = "pradeep"
print(name[2:4])
print(name[2:5:2])
print(name[:-2])
print(name[2:])
# Out:
# ad
# ae
# prade
# adeep

# %%
le = "pradeep"
x = len(le)
print(x)
# Out:
# 7

# %%
txt = " Hello my friends"
img = "file.png"
jo = "i", "am" , "pradeep"

a = txt.upper()
b = txt.lower()
c = txt.title()
d = txt.strip()
e = txt.replace("Hello", "oie")
f = img.endswith("png")
j = " ".join(jo)




print(a)
print(b)
print(c)
print(d)
print(e)
print(f)
print(j)
# Out:
#  HELLO MY FRIENDS
#  hello my friends
#  Hello My Friends
# Hello my friends
#  oie my friends
# True
# i am pradeep
