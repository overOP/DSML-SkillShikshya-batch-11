# %%
data = (1, "pradeep")
print(type(data))
# Out:
# <class 'tuple'>

# %%
data = ((1,2, "hari",[8,4,5]))
tuple(data)
# Out:
# (1, 2, 'hari', [8, 4, 5])

# %%
data = (1,2,3,4,5)
x = len(data)
print(x)
# Out:
# 5

# %%
data = (1,2,3,4,5)
x = max(data)
print(x)
# Out:
# 5

# %%
data = (1,2,3,4,5)
x = min(data)
print(x)
# Out:
# 1

# %%
data = (1,2,3,4,5)
x = sum(data)
print(x)
# Out:
# 15

# %%
data = (1,2,3,4,5)
x = any(data)
print(x)
# Out:
# True

# %%
data = (1,2,3,4,5)
x = all(data)
print(x)
# Out:
# True

# %%
data = (1,2,3,4,5)
x = sorted(data)
print(x)
# Out:
# [1, 2, 3, 4, 5]

# %%
data = ((1,2,3,4,5))
x = tuple(data)
print(x)
# Out:
# (1, 2, 3, 4, 5)

# %%
()
tuple()

# %%
1,2,3,4
# Out:
# (1, 2, 3, 4)

# %%
data = (1,2,3)
a = data[0]
b = data[1]
c = data[2]
print(a,b,c)
# Out:
# 1 2 3

# %%
dat = (1,2,3)
a,b,c = dat
print(a,b,c)
# _ is use to give a not use data
# Out:
# 1 2 3

# %%
t = (10,20,30)
#indexing
print(t[0])
# Out:
# 10

# %%
t1 = (10,20,30,40.5)
#$licing
print(t1[1:3])
# Out:
# (20, 30)

# %%
# concatenation
t2 = (1,2)
t3 = (3,4)
a = (t2 + t3)
print(a)
# Out:
# (1, 2, 3, 4)

# %%
t4 = (1,2)
# Repetitions
print(t4 * 3)
# Out:
# (1, 2, 1, 2, 1, 2)

# %%
t5 = (10,20,30)
# Membership
print(20 in t5)
# Out:
# True

# %%
t6 = (1,2)
t7 = (1,3)
# comparison
x = (t6 > t7)
print(x)
# Out:
# False

# %%
d = (1,2,3,4)
del d

# %%
s1 = {20, 'pradeep', 34.5}
print(s1)
print(type(s1))
# Out:
# {'pradeep', 34.5, 20}
# <class 'set'>

# %%
name_set = set(("pradeep", "i am a developer"))
print(name_set)
# Out:
# {'pradeep', 'i am a developer'}

# %%
dig = set({"1m",2,3})
print(dig)
# Out:
# {2, 3, '1m'}

# %%
setA = {1,2,3}
setB = {1,2}
x = setA - setB
print(x)
# Out:
# {3}

# %%
setA = {1,2,3}
setB = {1,2}
# union
x = setA | setB
print(x)
# Out:
# {1, 2, 3}

# %%
setA = {1,2,3}
setB = {1,2}
x = setA & setB
print(x)
# Out:
# {1, 2}

# %%
setA = {1,2,3}
setB = {3,4,5}
# Symmetric
x = setA ^ setB
print(x)
# Out:
# {1, 2, 4, 5}

# %%
A = {1,2,3}
# membership
print(2 in A)
# Out:
# True

# %%
A = {1,2}
B = {1,2,3}
# Subset
print(A <= B)
# Out:
# False

# %%
setA = {1,2,3}
setB = {1,2}
x = setA == setB
print(x)
# Out:
# False
