# %%
data = {
  "id": 101,
  "location": "Kathmandu, Nepal",
  "active": True,
  "login_attempts": 3,
  "preferences": ["dark_mode", "autosave"],
  "metadata": None,
  "contact" : {
      "email" : "cgpradeepop@gmail.com",
      "phone" : None
  }
}
print(type(data))
if data["active"] == True:
  print("this is ok")
else:
    print("not")
if data["active"] is True:
  print("ok")
else:
  ("no")
# Out:
# <class 'dict'>
# this is ok
# ok

# %%
data["id"]
# Out:
# 101

# %%
dict({
    "name": "pradeep",
    "number": 9812733452,
    "active": True
    })
# Out:
# {'name': 'pradeep', 'number': 9812733452}

# %%
dict({
    'student1': dict({
        'name': 'pradeep',
        'age': 24
    }),
    'student2': {
        'name': 'stuti',
        'age': 25
    }
})
# Out:
# {'student1': {'name': 'pradeep', 'age': 24},
#  'student2': {'name': 'stuti', 'age': 25}}

# %%
person = dict([
    ('name', 'pradeep'),
    ('country', 'nepal'),
    ('number', 98127334562)
    ])
print(person)
# Out:
# {'name': 'pradeep', 'country': 'nepal', 'number': 98127334562}

# %%
sample_dict = {
    'name': 'pradeep',
    10: 'Mobile'
}
print(sample_dict)
# Out:
# {'name': 'pradeep', 10: 'Mobile'}

# %%
person = {
    'name': 'pradeeep',
    'telephone': [
        9812733452,
        9810000000,
        9810000024
    ],

}
print(person)
print(person["telephone"][1])
# Out:
# {'name': 'pradeeep', 'telephone': [9812733452, 9810000000, 9810000024]}
# 9810000000

# %%
data = {
    'name': 'pradeep'
}
data['name'] = 'stuti'
print(data)
# Out:
# {'name': 'stuti'}

# %%
data = {
    'id': 1011,
    'name': 'pradeep'
}
x = data.keys()
print(x)
y = data.pop('name')
data.pop("name","not found")
print(y)
print(data)
# Out:
# dict_keys(['id', 'name'])
# {'id': 1011}

# %%
dd = {
    'id':10101,
    'name': 'pradeep'
}
z = dd.popitem()
print(z)
# Out:
# ('name', 'pradeep')

# %%
dta = {
    'id':10101,
    'name': 'pradeep'
}
print(dta)
del dta
print(dta)
# Out:
# {'id': 10101, 'name': 'pradeep'}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2124/2507715161.py in <cell line: 0>()
#       5 print(dta)
#       6 del dta
# ----> 7 print(dta)
#
# NameError: name 'dta' is not defined

# %%
dd11 = {
    'id':10101,
    'name': 'pradeep'
}
x = dd11.clear()
print(dd11)
# Out:
# {}

# %%
data = {
    'id': 1011,
    'name': 'pradeep'
}
y = data.pop('name')
x = data.pop('name',"not found")

print(y)
print(x)
print(data)
# Out:
# pradeep
# not found
# {'id': 1011}

# %%
# update
dood = {
    'id':120,
    'name': 'roshani',
    'age': 22
}
dood1 = {
    'id': 120,
    'name': 'pradeep',
    'age': 24
}
x = dood.update(dood1)
print(x)
print(dood)
# Out:
# None
# {'id': 120, 'name': 'pradeep', 'age': 24}

# %%
dod = {
    'id':120,
}
dod1 = {
    'name': 'pradeep',
}
dod2 = {
    'age': 24
}
dod3 = {
    'number': 9812733452
}
x = {**dod, **dod1, **dod2, **dod3}
print(x)
# Out:
# {'id': 120, 'name': 'pradeep', 'age': 24, 'number': 9812733452}

# %%
dod = {
    'id':120,
}
dod1 = {
    'name': 'pradeep',
}
dod2 = {
    'age': 24
}
dod3 = {
    'number': 9812733452
}
x = dod | dod1 | dod2 | dod3
print(x)
# Out:
# {'id': 120, 'name': 'pradeep', 'age': 24, 'number': 9812733452}

# %%
student = {'b':2,
           'a':1,
           'c':3
           }
result = sorted(student)
print(result)
# Out:
# ['a', 'b', 'c']

# %%
student_data = {
    'name': 'over',
    'age': 24,
    'facult': 'DSML'
}

student_data['age'] = 25

print(student_data)
# Out:
# {'name': 'over', 'age': 25, 'facult': 'DSML'}

# %%
student_data = {
    'name': 'over',
    'age': 24,
    'facult': 'DSML',
    'email': ""
}

if student_data['email'] == None:
  print('email is here')
else:
  print('give the email')

print(student_data)
# Out:
# give the email
# {'name': 'over', 'age': 24, 'facult': 'DSML', 'email': ''}
